# %%
import matplotlib.pyplot as plt

# %%
X = [1, 2, 3, 4]
Y = [5, 6, 7, 8]

plt.plot()  #line chart
plt.show()

# %%
oscar_movies = [
    "The Dark Knight"
    "The Hurt Locker"
    "The King's Speech"
    "The Artist"
    "Argo"
    
]
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]

plt.plot(years, oscar_revenue)
plt.title("This is  Oscar Movie Revenue in each Year")
plt.xlabel("Years")
plt.ylabel("Revenue (in M$)")
# Out:
# Text(0, 0.5, 'Revenue (in M$)')

# %%
non_oscar_movies = ["Slumdog", "Avatar", "Inception", "Hugo", "Lincon"]
non_oscar_revenue = [378, 2005, 571, 110, 220]
plt.plot(years, oscar_revenue, "o--r", label = "Oscar Winners")
plt.plot(years, non_oscar_revenue , label = "non oscar winners")


plt.title("Oscar-Movies VS Non-Oscar Movies Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue (in M$)")
plt.legend()

# %%
plt.plot(years, oscar_revenue, label = "Oscar Winners")
plt.plot(years, non_oscar_revenue , label = "non oscar winners")

plt.title("Oscar-Movies VS Non-Oscar Movies Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue (in M$)")
plt.legend()

plt.grid()

# %%
#bar chart
movies = [
    "The Dark Knight"
    "The Hurt Locker"
    "The King's Speech"
    "The Artist"
    "Argo"
    
]
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232]

plt.bar(years,revenue)
plt.title("Revenue in each year")
plt.xlabel("Years")
plt.ylabel("Revenue")

for i in range(len(years)) :
    plt.text(years[i], revenue[i]+10, str(revenue[i]), ha = "center")

# %%
import numpy as np
import matplotlib.pyplot as plt

oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
oscar_revenue = [1005, 170, 427, 133, 232]

non_oscar_movies = ["Slumdog", "Avatar", "Inception", "Hugo", "Lincoln"]
non_oscar_revenue = [378, 2005, 571, 110, 220]

years = [2008, 2009, 2010, 2011, 2012]

x = np.arange(len(years))
width = 0.4

plt.bar(x - width/2, oscar_revenue, width, label="Oscar Movies")
plt.bar(x + width/2, non_oscar_revenue, width, label="Non-Oscar Movies")

plt.title("Oscar Movies vs Non-Oscar Movies Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue (in M$)")
plt.xticks(x, years)       # set the x-axis tick labels
plt.legend()

plt.show()

# %%
#scatter plot

people = ["person A","person B","person C","person D","person E",
          "person F","person G","person H","person I","person J",]
age = [22,25,30,35,40,45,50,55,60,65]
blood_pressure = [110,115,120,122,125,130,135,123,140,150]

plt.scatter(age, blood_pressure, color ="red")
plt.title("Age VS Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.grid()

for i in range (len(people)):
    plt.annotate(people[i], xy = (age[i], blood_pressure[i]) , xytext = (age[i]+2, blood_pressure[i]))

# %%
# Multiple scatter plots
cities = ["City A", "City B", "City C", "City D", "City E"]

# Winter: Temperature (°C) vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Summer: Temperature (°C) vs Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

# Plots
plt.scatter(winter_temp, winter_humidity, color="blue", label="Winter")
plt.scatter(summer_temp, summer_humidity, color="orange", label="Summer")

plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.legend()

# %%
 #pie chart

expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]
amount = [500, 150, 120, 100, 50]

plt.pie( amount, labels = expenses)
# Out:
# ([<matplotlib.patches.Wedge at 0x224a5296c10>,
# ...
#  [Text(-0.14978333189343454, 1.089754538181375, 'Salaries'),
#   Text(-0.7778173279449521, -0.7778175906654303, 'Rent'),
#   Text(0.14978329725394143, -1.0897545429424635, 'Marketing'),
#   Text(0.8532823048810049, -0.6941968799821562, 'R&D'),
#   Text(1.0840054194235482, -0.18690171390433388, 'Miscellaneous')])

# %%
#histogram
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(0)

scores = np.random.normal(50,10,1000)
plt.hist(scores, color = "skyblue", edgecolor = "black", bins = 5)
plt.axvline(
    x = 33,
    label = "passing marks(33)",
    color = "red",
)
plt.xlabel("Scores")
plt.ylabel("No. of students")
# Out:
# Text(0, 0.5, 'No. of students')

# %%
#box plot

data = [7,8,5,4,6,2,9,12,13,15]
plt.boxplot(data, vert=False, showmeans=True)
plt.grid(True)

# %%
group1 = np.random.normal(50,10,100)
group2 = np.random.normal(60,15,100)

plt.boxplot([group1, group2], tick_labels = ["group1", "group2"])
plt.show()
